# %%
from ultralytics import YOLO

# %%
TRAINED_MODEL_PATH = '/app/src/training/outputs/train/weights/best.pt'
MODEL_DATA_FILE = "/app/src/training/database.yaml"

# %%
trained_model = YOLO(TRAINED_MODEL_PATH)
results = trained_model.val(data=MODEL_DATA_FILE)
# Out:
# Ultralytics YOLOv8.0.201 🚀 Python-3.10.11 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 4070, 12282MiB)
# val: Scanning /app/data/yolo/Val.cache... 105 images, 0 backgrounds, 0 corrupt: 100%|██████████| 105/105 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:04<00:00,  1.67it/s]
#                    all        105        114      0.673       0.56      0.632      0.296
# Speed: 0.5ms preprocess, 5.0ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to runs/detect/val2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7f363cb95ae0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# ...
